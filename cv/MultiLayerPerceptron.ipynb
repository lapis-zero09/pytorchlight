# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

# %% [markdown]
# # load data

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
#                        transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=256, shuffle=True)

# %%
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
#                        transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=256, shuffle=True)

# %%
image, label = iter(train_loader).next()
image.__class__, label.__class__, image.size(), label.size()
# Out:
# (torch.FloatTensor,
#  torch.LongTensor,
#  torch.Size([256, 1, 28, 28]),
#  torch.Size([256]))

# %% [markdown]
# ## visualization

# %%
import matplotlib.pyplot as plt
import numpy as np
from torchvision.utils import make_grid
# %matplotlib inline

# %%
make_grid(image[:5]).numpy().shape
# Out:
# (3, 32, 152)

# %%
img = make_grid(image[:25], nrow=5, padding=1).numpy()
t = np.transpose(img, (1, 2, 0))
plt.imshow(t)

# %% [markdown]
# # train

# %%
class MultiLayerPerceptron(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        # layerの定義
        super(MultiLayerPerceptron, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %%
model = MultiLayerPerceptron(input_size=784, hidden_size=500, num_classes=10).cuda()
image = image.view(-1, 28 * 28)

# model()

# %%
model
# Out:
# MultiLayerPerceptron(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
optimizer = optim.SGD(model.parameters(), lr=0.001)

def train(train_loader):
    model.train()
    train_loss = 0
    for batch_idx, (x, y) in enumerate(train_loader):
        x, y = x.view(-1, 28 * 28).cuda(), y.cuda()
        b_x = Variable(x)
        b_y = Variable(y)
        
        optimizer.zero_grad()
        output = model(b_x)
        loss = F.cross_entropy(output, b_y)
        train_loss += loss.data[0]
        loss.backward()
        optimizer.step()
        
    train_loss = train_loss / len(train_loader)
    return train_loss

def valid(test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    for x, y in test_loader:
        x, y = x.view(-1, 28 * 28).cuda(), y.cuda()
        b_x = Variable(x, volatile=True)
        b_y = Variable(y, volatile=True)
        
        outputs = model(b_x)
        test_loss += F.cross_entropy(outputs, b_y).data[0]
#         _, predicted = torch.max(outputs.data, 1)
#         correct += (predicted == b_y.data).sum()
        pred = outputs.data.max(1, keepdim=True)[1]
        correct += pred.eq(b_y.data.view_as(pred)).cpu().sum()
        total += b_y.size(0)
        
    val_loss = test_loss / len(test_loader)
    val_acc = correct / total
    return val_loss, val_acc

# %%
loss_list = []
val_loss_list = []
val_acc_list = []

for epoch in range(100):
    loss = train(train_loader)
    val_loss, val_acc = valid(test_loader)
    print('epoch %d, loss: %.4f val_loss: %.4f val_acc: %.4f' % (epoch, loss, val_loss, val_acc))
    
    # logging
    loss_list.append(loss)
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)
# Out:
# epoch 0, loss: 2.2717 val_loss: 2.2419 val_acc: 0.3205
# epoch 1, loss: 2.2156 val_loss: 2.1841 val_acc: 0.4827
# epoch 2, loss: 2.1587 val_loss: 2.1239 val_acc: 0.5919
# epoch 3, loss: 2.0986 val_loss: 2.0595 val_acc: 0.6657
# epoch 4, loss: 2.0338 val_loss: 1.9910 val_acc: 0.7052
# epoch 5, loss: 1.9643 val_loss: 1.9146 val_acc: 0.7260
# epoch 6, loss: 1.8897 val_loss: 1.8391 val_acc: 0.7370
# epoch 7, loss: 1.8112 val_loss: 1.7597 val_acc: 0.7484
# epoch 8, loss: 1.7296 val_loss: 1.6718 val_acc: 0.7562
# epoch 9, loss: 1.6464 val_loss: 1.5871 val_acc: 0.7628
# epoch 10, loss: 1.5637 val_loss: 1.5082 val_acc: 0.7698
# epoch 11, loss: 1.4829 val_loss: 1.4229 val_acc: 0.7779
# epoch 12, loss: 1.4053 val_loss: 1.3452 val_acc: 0.7847
# epoch 13, loss: 1.3316 val_loss: 1.2749 val_acc: 0.7911
# epoch 14, loss: 1.2628 val_loss: 1.2059 val_acc: 0.7972
# epoch 15, loss: 1.1994 val_loss: 1.1509 val_acc: 0.8062
# epoch 16, loss: 1.1409 val_loss: 1.0913 val_acc: 0.8124
# epoch 17, loss: 1.0877 val_loss: 1.0344 val_acc: 0.8173
# epoch 18, loss: 1.0392 val_loss: 0.9932 val_acc: 0.8201
# epoch 19, loss: 0.9953 val_loss: 0.9454 val_acc: 0.8244
# epoch 20, loss: 0.9553 val_loss: 0.9092 val_acc: 0.8292
# epoch 21, loss: 0.9189 val_loss: 0.8789 val_acc: 0.8324
# epoch 22, loss: 0.8860 val_loss: 0.8422 val_acc: 0.8360
# epoch 23, loss: 0.8558 val_loss: 0.8167 val_acc: 0.8391
# epoch 24, loss: 0.8279 val_loss: 0.7904 val_acc: 0.8401
# epoch 25, loss: 0.8026 val_loss: 0.7682 val_acc: 0.8432
# epoch 26, loss: 0.7789 val_loss: 0.7421 val_acc: 0.8455
# epoch 27, loss: 0.7578 val_loss: 0.7182 val_acc: 0.8482
# epoch 28, loss: 0.7378 val_loss: 0.7025 val_acc: 0.8505
# epoch 29, loss: 0.7194 val_loss: 0.6833 val_acc: 0.8517
# epoch 30, loss: 0.7021 val_loss: 0.6738 val_acc: 0.8547
# epoch 31, loss: 0.6866 val_loss: 0.6509 val_acc: 0.8561
# epoch 32, loss: 0.6717 val_loss: 0.6478 val_acc: 0.8587
# epoch 33, loss: 0.6578 val_loss: 0.6250 val_acc: 0.8606
# epoch 34, loss: 0.6449 val_loss: 0.6131 val_acc: 0.8622
# epoch 35, loss: 0.6331 val_loss: 0.6061 val_acc: 0.8641
# epoch 36, loss: 0.6216 val_loss: 0.5900 val_acc: 0.8665
# epoch 37, loss: 0.6105 val_loss: 0.5772 val_acc: 0.8676
# epoch 38, loss: 0.6006 val_loss: 0.5689 val_acc: 0.8693
# epoch 39, loss: 0.5911 val_loss: 0.5597 val_acc: 0.8708
# epoch 40, loss: 0.5820 val_loss: 0.5505 val_acc: 0.8724
# epoch 41, loss: 0.5735 val_loss: 0.5474 val_acc: 0.8743
# epoch 42, loss: 0.5651 val_loss: 0.5378 val_acc: 0.8752
# epoch 43, loss: 0.5572 val_loss: 0.5276 val_acc: 0.8763
# epoch 44, loss: 0.5502 val_loss: 0.5216 val_acc: 0.8770
# epoch 45, loss: 0.5432 val_loss: 0.5115 val_acc: 0.8772
# epoch 46, loss: 0.5364 val_loss: 0.5100 val_acc: 0.8791
# epoch 47, loss: 0.5307 val_loss: 0.5024 val_acc: 0.8801
# epoch 48, loss: 0.5243 val_loss: 0.4974 val_acc: 0.8810
# epoch 49, loss: 0.5181 val_loss: 0.4897 val_acc: 0.8817
# epoch 50, loss: 0.5127 val_loss: 0.4813 val_acc: 0.8827
# epoch 51, loss: 0.5075 val_loss: 0.4786 val_acc: 0.8835
# epoch 52, loss: 0.5027 val_loss: 0.4741 val_acc: 0.8841
# epoch 53, loss: 0.4974 val_loss: 0.4699 val_acc: 0.8851
# epoch 54, loss: 0.4927 val_loss: 0.4694 val_acc: 0.8858
# epoch 55, loss: 0.4882 val_loss: 0.4645 val_acc: 0.8860
# epoch 56, loss: 0.4842 val_loss: 0.4618 val_acc: 0.8863
# epoch 57, loss: 0.4799 val_loss: 0.4586 val_acc: 0.8869
# epoch 58, loss: 0.4757 val_loss: 0.4562 val_acc: 0.8876
# epoch 59, loss: 0.4725 val_loss: 0.4454 val_acc: 0.8886
# epoch 60, loss: 0.4681 val_loss: 0.4390 val_acc: 0.8887
# epoch 61, loss: 0.4647 val_loss: 0.4379 val_acc: 0.8894
# epoch 62, loss: 0.4609 val_loss: 0.4429 val_acc: 0.8896
# epoch 63, loss: 0.4578 val_loss: 0.4336 val_acc: 0.8901
# epoch 64, loss: 0.4545 val_loss: 0.4288 val_acc: 0.8905
# epoch 65, loss: 0.4512 val_loss: 0.4327 val_acc: 0.8913
# epoch 66, loss: 0.4485 val_loss: 0.4265 val_acc: 0.8912
# epoch 67, loss: 0.4451 val_loss: 0.4204 val_acc: 0.8918
# epoch 68, loss: 0.4428 val_loss: 0.4195 val_acc: 0.8928
# epoch 69, loss: 0.4399 val_loss: 0.4190 val_acc: 0.8933
# epoch 70, loss: 0.4373 val_loss: 0.4100 val_acc: 0.8940
# epoch 71, loss: 0.4343 val_loss: 0.4197 val_acc: 0.8945
# epoch 72, loss: 0.4319 val_loss: 0.4161 val_acc: 0.8951
# epoch 73, loss: 0.4292 val_loss: 0.4020 val_acc: 0.8957
# epoch 74, loss: 0.4268 val_loss: 0.4029 val_acc: 0.8958
# epoch 75, loss: 0.4245 val_loss: 0.3979 val_acc: 0.8962
# epoch 76, loss: 0.4222 val_loss: 0.3961 val_acc: 0.8964
# epoch 77, loss: 0.4198 val_loss: 0.3961 val_acc: 0.8961
# epoch 78, loss: 0.4178 val_loss: 0.3969 val_acc: 0.8967
# epoch 79, loss: 0.4160 val_loss: 0.3923 val_acc: 0.8973
# epoch 80, loss: 0.4139 val_loss: 0.3937 val_acc: 0.8976
# epoch 81, loss: 0.4117 val_loss: 0.3901 val_acc: 0.8981
# epoch 82, loss: 0.4101 val_loss: 0.3904 val_acc: 0.8982
# epoch 83, loss: 0.4076 val_loss: 0.3845 val_acc: 0.8983
# epoch 84, loss: 0.4064 val_loss: 0.3956 val_acc: 0.8983
# epoch 85, loss: 0.4042 val_loss: 0.3829 val_acc: 0.8984
# epoch 86, loss: 0.4025 val_loss: 0.3773 val_acc: 0.8990
# epoch 87, loss: 0.4008 val_loss: 0.3790 val_acc: 0.8992
# epoch 88, loss: 0.3991 val_loss: 0.3767 val_acc: 0.8992
# epoch 89, loss: 0.3977 val_loss: 0.3882 val_acc: 0.8993
# epoch 90, loss: 0.3962 val_loss: 0.3705 val_acc: 0.8997
# epoch 91, loss: 0.3943 val_loss: 0.3695 val_acc: 0.8998
# epoch 92, loss: 0.3929 val_loss: 0.3702 val_acc: 0.9003
# epoch 93, loss: 0.3915 val_loss: 0.3679 val_acc: 0.9005
# epoch 94, loss: 0.3900 val_loss: 0.3719 val_acc: 0.9003
# epoch 95, loss: 0.3886 val_loss: 0.3722 val_acc: 0.9004
# epoch 96, loss: 0.3866 val_loss: 0.3651 val_acc: 0.9007
# epoch 97, loss: 0.3857 val_loss: 0.3621 val_acc: 0.9006
# epoch 98, loss: 0.3845 val_loss: 0.3732 val_acc: 0.9011
# epoch 99, loss: 0.3827 val_loss: 0.3573 val_acc: 0.9013

# %%
plt.figure()
plt.plot(range(100), loss_list, 'r-', label='train_loss')
plt.plot(range(100), val_loss_list, 'b-', label='val_loss')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.grid()

plt.figure()
plt.plot(range(100), val_acc_list, 'g-', label='val_acc')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.grid()

# %%
a = Variable(iter(test_loader).next()[0].view(-1, 28 * 28).cuda())[0]
a
# Out:
# Variable containing:
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.4039
#  0.8941
#  0.8667
#  0.1255
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.1686
#  0.6314
#  0.9882
#  0.9922
#  0.9922
#  0.4902
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.8471
#  0.9922
#  0.9922
#  0.9922
#  0.9922
#  0.9804
#  0.3569
#  0.4392
#  0.5137
#  0.6157
#  0.3922
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.3569
#  0.9843
#  0.9922
#  0.9922
#  0.9922
#  0.9922
#  0.8980
#  0.8431
#  0.9922
#  0.9922
#  0.9922
#  0.9843
#  0.5843
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.1608
#  0.4235
#  0.9922
#  0.9922
#  0.9922
#  0.8824
#  0.3490
#  0.5843
#  0.2157
#  0.0980
#  0.0980
#  0.4314
#  0.8471
#  0.9843
#  0.3922
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.8588
#  0.9294
#  0.9922
#  0.9922
#  0.8824
#  0.1922
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.1294
#  0.6627
#  0.8784
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.8039
#  0.9804
#  0.9922
#  0.9922
#  0.5373
#  0.1059
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0784
#  0.9569
#  0.5882
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.5373
#  0.9843
#  0.6549
#  0.1765
#  0.4392
#  0.0275
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0549
#  0.8588
#  0.9765
#  0.1529
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.3922
#  0.9882
#  0.9922
#  0.5843
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0627
#  0.9059
#  0.9922
#  0.4824
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.6157
#  0.9922
#  0.6549
#  0.1333
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0784
#  0.9922
#  0.9922
#  0.4824
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  1.0000
#  0.9922
#  0.4431
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.1961
#  0.9922
#  0.9882
#  0.3725
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  1.0000
#  0.9922
#  0.0471
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0745
#  0.8784
#  0.9922
#  0.9686
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.9059
#  0.9922
#  0.0471
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.1176
#  0.5255
#  0.9922
#  0.8667
#  0.2980
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.4902
#  0.9922
#  0.0471
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0275
#  0.6941
#  0.9922
#  0.9922
#  0.4314
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.5529
#  0.9922
#  0.0471
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.1176
#  0.6941
#  0.9922
#  0.9804
#  0.5608
#  0.1569
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.6824
#  0.9922
#  0.1020
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0275
#  0.4745
#  0.6824
#  0.9922
#  0.9922
#  0.8392
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.4902
#  0.9922
#  0.8157
#  0.0431
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0235
#  0.5529
#  0.9922
#  0.9922
#  0.9804
#  0.8510
#  0.1569
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.2118
#  0.9294
#  0.9922
#  0.5922
#  0.5608
#  0.1176
#  0.2235
#  0.5608
#  0.5608
#  0.6745
#  0.9922
#  0.9922
#  0.9843
#  0.5294
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.9333
#  0.9922
#  0.9922
#  0.9922
#  0.9922
#  0.9922
#  0.9922
#  0.9922
#  0.9882
#  0.8627
#  0.3765
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.2118
#  0.6902
#  0.9922
#  0.5451
#  0.7451
#  0.4824
#  0.7451
#  0.4824
#  0.3725
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# [torch.cuda.FloatTensor of size 784 (GPU 0)]

# %%
outputs = model(a)
outputs
# Out:
# Variable containing:
#  7.5822
# -5.4427
#  1.1578
#  2.7127
# -6.2160
#  4.5641
# -1.8519
# -1.7551
#  1.5943
# -2.3275
# [torch.cuda.FloatTensor of size 10 (GPU 0)]

# %%
outputs.data
torch.max(outputs.data, -1)
# Out:
# (
#   7.5822
#  [torch.cuda.FloatTensor of size 1 (GPU 0)],
#   0
#  [torch.cuda.LongTensor of size 1 (GPU 0)])

# %%
outputs.data.max(-1, keepdim=True)
# Out:
# (
#   7.5822
#  [torch.cuda.FloatTensor of size 1 (GPU 0)],
#   0
#  [torch.cuda.LongTensor of size 1 (GPU 0)])
